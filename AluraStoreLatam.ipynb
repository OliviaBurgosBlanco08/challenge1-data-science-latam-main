# %% [markdown]
# <a href="https://colab.research.google.com/github/OliviaBurgosBlanco08/challenge1-data-science-latam-main/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
#agregar columa de facturacion individual
tienda['Facturacion'] = tienda['Precio'] * tienda['Costo de envío']

# %%
#Facturacion total
facturacion_total = tienda['Facturacion'].sum()
print(f"La facturacion total es de: {facturacion_total:,.2f}")
# Out:
# La facturacion total es de: 77,467,957,090,000.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_por_categoria = tienda.groupby("Categoría del Producto")["Facturacion"].sum().sort_values(ascending=False)
print(ventas_por_categoria)
# Out:
# Categoría del Producto
# Electrónicos               4.042072e+13
# Electrodomésticos          2.764457e+13
# Muebles                    4.959837e+12
# Instrumentos musicales     3.420414e+12
# Deportes y diversión       8.245436e+11
# Juguetes                   1.020775e+11
# Artículos para el hogar    7.050367e+10
# Libros                     2.529279e+10
# Name: Facturacion, dtype: float64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_promedio = tienda['Calificación'].mean()
print(f"La calificacion promedio es de: {calificacion_promedio:,.2f}")
# Out:
# La calificacion promedio es de: 3.98

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
productos_mas_vendidos = tienda.groupby("Producto")["Cantidad de cuotas"].sum().sort_values(ascending=False)
print(productos_mas_vendidos)
# Out:
# Producto
# Secadora de ropa               214
# TV LED UHD 4K                  196
# Mesa de noche                  188
# Impresora                      182
# Bicicleta                      178
# Balón de baloncesto            167
# Guitarra eléctrica             167
# Sofá reclinable                163
# Silla de oficina               161
# Bloques de construcción        161
# Microondas                     159
# Sillón                         155
# Auriculares                    152
# Smart TV                       151
# Cama box                       150
# Lavavajillas                   150
# Cubertería                     148
# Carrito de control remoto      145
# Armario                        145
# Batería                        143
# Ciencia de datos con Python    141
# Guitarra acústica              140
# Lavadora de ropa               137
# Modelado predictivo            137
# Balón de voleibol              136
# Iphone 15                      134
# ...

# %%
productos_menos_vendidos = tienda.groupby("Producto")["Cantidad de cuotas"].sum().sort_values(ascending=True)
print(productos_menos_vendidos)
# Out:
# Producto
# Celular ABXY                    78
# Mochila                         90
# Dinosaurio Rex                  94
# Tablet ABXY                     99
# Cuerda para saltar             100
# Set de vasos                   101
# Cubo mágico 8x8                101
# Auriculares con micrófono      103
# Olla de presión                108
# Iniciando en programación      113
# Smartwatch                     117
# Mesa de comedor                118
# Kit de bancas                  119
# Estufa                         120
# Mesa de centro                 121
# Juego de mesa                  121
# Muñeca bebé                    121
# Pandereta                      123
# Vaso térmico                   125
# Cama king                      126
# Refrigerador                   126
# Asistente virtual              129
# Dashboards con Power BI        129
# Ajedrez de madera              129
# Set de ollas                   132
# Iphone 15                      134
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_promedio = tienda.groupby("Lugar de Compra")["Costo de envío"].mean()
print(envio_promedio)
# Out:
# Lugar de Compra
# Armenia          17314.285714
# Barranquilla     23708.000000
# Bogotá           23815.853659
# Bucaramanga      30587.096774
# Cali             28827.561837
# Cartagena        22624.528302
# Cúcuta           40129.411765
# Inírida          28460.000000
# Leticia          24450.000000
# Manizales        29140.000000
# Medellín         28207.104796
# Neiva            31516.666667
# Pasto            35078.260870
# Pereira          22403.759398
# Riohacha         24357.500000
# Santa Marta      22593.750000
# Soacha           43420.000000
# Valledupar       18766.666667
# Villavicencio    34709.090909
# Name: Costo de envío, dtype: float64
